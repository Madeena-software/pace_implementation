# %% [markdown]
# # Full Image Processing Pipeline - Step by Step
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Madeena-software/pace_implementation/blob/main/playground.ipynb)
#
# > **Colab users:** Go to **Runtime → Change runtime type → GPU** before running.
#
# Complete medical image processing pipeline based on PACE (Siracusano et al. 2020) and PACE 2.0 (Siracusano et al. 2023).
# All parameters are configured in **Step 0b** — adjust values there and re-run to experiment.
#
# | Step | Name | Key Parameters |
# |------|------|----------------|
# | 0b | **Setup & Config** | All paths, method selections, and tuning parameters |
# | 1 | **Load Images** | `PROJ_IMG_PATH`, `GAIN_IMG_PATH`, `DARK_IMG_PATH` |
# | 2 | **Flat Field Correction** | `FFC_MEDIAN_SIZE` |
# | 3 | **Spatial Calibration** | `CALIB_PATH` |
# | 4 | **Decomposition (BEMD/FABEMD)** | `DECOMPOSITION_METHOD`, BEMD_*/FABEMD_* params |
# | 5 | **Homomorphic Filtering** | `HOMOMORPHIC_METHOD`, `D0`, γ_H, γ_L, order |
# | 6 | **Nonlinear Filtering & Reconstruction** | `DENOISE_METHOD`, `DENOISE_R`, `DENOISE_BETA`, NL-means params |
# | 7 | **Gamma Correction** | `GAMMA` |
# | 8 | **CLAHE Enhancement** | `CLAHE_CLIP`, `CLAHE_TILE` |
# | 9 | **Background Masking** | `PRESERVE_ZERO_BACKGROUND`, `BACKGROUND_ZERO_THRESHOLD` |
# | 10 | **Image Quality Metrics** | CII, Entropy, EME evaluation |
# | 11 | **Normalize & Resize** | `OUTPUT_WIDTH` |
# | 12 | **Final Comparison** | All stages side-by-side |

# %%
# ============================================================
# Step 0a: Environment Setup (Colab / Local)
# ============================================================
import os

IS_COLAB = "COLAB_RELEASE_TAG" in os.environ

if IS_COLAB:
    # --- Clone the repository ---
    if not os.path.isdir("pace_implementation"):
        # !git clone https://github.com/Madeena-software/pace_implementation.git
    os.chdir("pace_implementation")

    # --- Install GPU dependencies ---
    # !pip install -q cupy-cuda12x opencv-python-headless

    # --- Mount Google Drive (for your image data) ---
    from google.colab import drive
    drive.mount("/content/drive", force_remount=False)
    DRIVE_ROOT = "/content/drive/MyDrive"  # adjust subfolder below

    print(f"\nGoogle Drive mounted at {DRIVE_ROOT}")
else:
    DRIVE_ROOT = ""  # not used locally

print(f"IS_COLAB     : {IS_COLAB}")
print(f"Working dir  : {os.getcwd()}")
# Out:
# IS_COLAB     : False
# Working dir  : c:\Users\wonga\repo\pace_implementation

# %%
# ============================================================
# Step 0b: Imports & Configuration
# ============================================================
import gc, sys
import cv2
import numpy as np
import matplotlib.pyplot as plt

# --- CuPy / NumPy fallback ---
try:
    import cupy as cp
    HAS_CUPY = True
except ImportError:
    import numpy as cp          # alias so cp.xxx calls still work
    HAS_CUPY = False

def _to_numpy(arr):
    """Safely move array to CPU (no-op when CuPy is absent)."""
    return arr.get() if hasattr(arr, 'get') else np.asarray(arr)

sys.path.insert(0, os.path.abspath("."))

from image_pipeline import (
    PipelineConfig,
    FlatFieldCorrection,
    SpatialCalibration,
    BEMD,
    HomomorphicFilter,
    PACEHomomorphicFilter,
    NonlinearFilter,
    NLMeansFilter,
    ImageEnhancer,
    ImageMetrics,
    ImageResizer,
)
from fabemd import FABEMD

# ===================== IMAGE PATHS =====================
# Projection : raw X-ray capture to process
# Gain       : uniform-illumination image (detector sensitivity map)
# Dark       : no-illumination image (electronic noise baseline)
# Calibration: .npz file with camera_matrix, dist_coeffs, roi from checkerboard calibration
PROJ_IMG_PATH  = "datacitra/Data_mentah/3-WWI-03B_Thorax_PA 3-WWI-03B 90kV40mA0,50s -8_7_2024-9.47 AM [Administrator].mdn"
GAIN_IMG_PATH  = "datacitra/Gain/Trx/90_40_0,50.mdn"
DARK_IMG_PATH  = "datacitra/Dark/Trx/dark.mdn"
CALIB_PATH     = "datacitra/Kalibrasi/trx_44_35.npz"

# ===================== FLAT FIELD CORRECTION =====================
# ffc_median_size : odd-integer kernel size for median filtering the gain image.
#   Removes hot/dead pixels from gain before FFC.  Larger = smoother gain.
#   Typical range: 3-11.
FFC_MEDIAN_SIZE = 7

# ===================== DECOMPOSITION METHOD =====================
# "bemd"   : classic Bidimensional EMD -- iterative surface interpolation (slower)
# "fabemd" : Fast & Adaptive BEMD (Bhuiyan 2008) -- order-statistics filters (faster, recommended)
DECOMPOSITION_METHOD = "fabemd"

# ===================== BEMD PARAMETERS =====================
# (used when DECOMPOSITION_METHOD = "bemd")
# BEMD_MAX_ITER      : max sifting iterations per BIMF. More = finer BIMFs, slower. Range: 1-10.
# BEMD_THRESHOLD     : SD stopping criterion. Lower = stricter convergence. Range: 0.1-2.0.
# BEMD_WINDOW_SIZE   : initial window (px) for extrema detection. Smaller = finer first BIMF. Range: 16-64.
# BEMD_EXTREMA_COUNT : min extrema to continue decomposition. Higher = fewer BIMFs. Range: 5-20.
BEMD_MAX_ITER      = 1
BEMD_THRESHOLD     = 1.0
BEMD_WINDOW_SIZE   = 32
BEMD_EXTREMA_COUNT = 10

# ===================== FABEMD PARAMETERS =====================
# (used when DECOMPOSITION_METHOD = "fabemd")
# FABEMD_MAX_SIFT       : max sifting iterations per BIMF. Range: 1-20.
# FABEMD_SD_THRESH      : SD stopping criterion. Lower = more refined. Range: 0.05-0.5.
# FABEMD_MIN_EXTREMA    : min extrema in residue to keep extracting BIMFs. Lower = more BIMFs. Range: 2-10.
# FABEMD_MAX_BIMFS      : hard cap on BIMFs (safety limit). Range: 10-200.
# FABEMD_WIN_CAP        : max window size (px) for order-statistics filters. Must be odd. Range: 101-2001.
# FABEMD_EXTREMA_WIN    : window for local extrema detection (max/min filter). Must be odd. Range: 3-9.
# FABEMD_INITIAL_WINDOW : starting window floor (px). None = adaptive first window from extrema spacing.
#   Integer values are normalized to odd and clamped by FABEMD_WIN_CAP; later BIMFs remain adaptive.
# FABEMD_GROWTH_RATE    : max factor by which window can grow per BIMF step.
#   Controls how gradually windows scale from small (edges) to large (contrast).
#   1.5 = max 50% growth per step (gradual). 2.0 = 100% growth (faster, fewer BIMFs).
#   Smaller values produce more intermediate BIMFs. Range: 1.2-3.0.
FABEMD_MAX_SIFT    = 1
FABEMD_SD_THRESH   = 0.2
FABEMD_MIN_EXTREMA = 5
FABEMD_MAX_BIMFS   = 20
FABEMD_WIN_CAP     = 2000
FABEMD_EXTREMA_WIN = 5
FABEMD_INITIAL_WINDOW = None  # e.g. 32 to force the first window floor; None keeps adaptive
FABEMD_GROWTH_RATE = 2

# ===================== HOMOMORPHIC FILTER =====================
# Operates in log-frequency domain: log -> FFT -> emphasis filter -> IFFT -> exp
# Separates illumination (low-freq) from reflectance (high-freq).
#
# HOMOMORPHIC_METHOD : "gaussian" (smooth roll-off) or "butterworth" (sharp roll-off, PACE paper)
# D0                 : cutoff frequency (px from center of freq. domain).
#                      Lower = more aggressive illumination flattening. Range: 10-80.
# RH                 : high-frequency gain (gamma_H). >1 amplifies detail. Range: 1.2-3.0.  (Gaussian only)
# RL                 : low-frequency gain (gamma_L). <1 suppresses slow variations. Range: 0.1-0.9.  (Gaussian only)
# PACE_GAMMA_H       : high-freq gain for Butterworth. Same meaning as RH. Range: 1.2-3.0.
# PACE_GAMMA_L       : low-freq gain for Butterworth. Close to 1.0 = preserve lighting. Range: 0.1-1.0.
# PACE_BW_ORDER      : Butterworth filter order (n).
#                      Higher n = sharper cutoff transition. 1 ~ Gaussian; 2+ = steep. Range: 1-4.
HOMOMORPHIC_METHOD = "gaussian"
D0 = 40
RH = 2.5
RL = 0.99
PACE_GAMMA_H = 0
PACE_GAMMA_L = 0
PACE_BW_ORDER = 2

# ===================== ENHANCEMENT =====================
# GAMMA      : gamma correction exponent. <1 brightens (good for dark X-rays). Range: 0.5-1.5.
# CLAHE_CLIP : max contrast amplification per tile. Higher = stronger but noisier. Range: 1.0-10.0.
# CLAHE_TILE : tile grid (rows, cols). More tiles = more local enhancement. Typical: (4,4)-(16,16).
GAMMA      = 0.8
CLAHE_CLIP = 3.0
CLAHE_TILE = (8, 8)

# ===================== BACKGROUND PRESERVATION =====================
# Preserve the invalid black field outside the calibrated detector ROI.
# Pixels at or below this threshold in the calibrated image stay zero after gamma/CLAHE.
PRESERVE_ZERO_BACKGROUND = True
BACKGROUND_ZERO_THRESHOLD = 0.0

# ===================== NONLINEAR FILTER (DENOISING) =====================
# Denoises the R lowest-energy BIMFs, then reconstructs:
#   I_out = sum BIMF_i* + beta * filtered_residue
#
# DENOISE_METHOD  : "bilateral" (edge-preserving, fast) or "nlmeans" (patch-based, better textures)
# DENOISE_R       : number of lowest-energy BIMFs to denoise (R). Range: 1-3.
# DENOISE_BETA    : weight (beta) of filtered residue in reconstruction.
#                   0 = omit residue; 1 = full weight; >1 = amplify. Range: 0.3-1.5.
DENOISE_METHOD = "nlmeans"
DENOISE_R    = 1
DENOISE_BETA = 1

# ===================== NL-MEANS PARAMETERS =====================
# (used when DENOISE_METHOD = "nlmeans")
# NLMEANS_H        : filter strength (h). Higher = more denoising, may blur. Range: 5-30.
# NLMEANS_TEMPLATE : comparison patch size (odd). Larger = more context, slower. Range: 5-11.
# NLMEANS_SEARCH   : search neighborhood size (odd). Larger = better matches, O(search^2). Range: 11-35.
NLMEANS_H = 10.0
NLMEANS_TEMPLATE = 7
NLMEANS_SEARCH = 21

# ===================== OUTPUT =====================
# OUTPUT_WIDTH : target width in pixels for final resize (aspect ratio preserved). 0 = skip resize.
OUTPUT_WIDTH = 4096

print("Step 0b: Imports & Configuration loaded")
print(f"   Projection : {PROJ_IMG_PATH}")
print(f"   Gain       : {GAIN_IMG_PATH}")
print(f"   Dark       : {DARK_IMG_PATH}")
print(f"   Calibration: {CALIB_PATH}")
print(f"   FFC median : {FFC_MEDIAN_SIZE}")
print(f"   Decomp.    : {DECOMPOSITION_METHOD}")
print(f"   BEMD       : max_iter={BEMD_MAX_ITER}, threshold={BEMD_THRESHOLD}, window={BEMD_WINDOW_SIZE}, extrema={BEMD_EXTREMA_COUNT}")
print(f"   FABEMD     : max_sift={FABEMD_MAX_SIFT}, sd={FABEMD_SD_THRESH}, min_ext={FABEMD_MIN_EXTREMA}, "
      f"max_bimfs={FABEMD_MAX_BIMFS}, win_cap={FABEMD_WIN_CAP}, initial={FABEMD_INITIAL_WINDOW}, "
      f"growth={FABEMD_GROWTH_RATE}")
print(f"   Homomorphic: {HOMOMORPHIC_METHOD} (D0={D0}, Rh={RH}, Rl={RL})")
if HOMOMORPHIC_METHOD == "butterworth":
    print(f"     Butterworth: gamma_h={PACE_GAMMA_H}, gamma_l={PACE_GAMMA_L}, order={PACE_BW_ORDER}")
print(f"   Enhancement: gamma={GAMMA}, CLAHE clip={CLAHE_CLIP}, tile={CLAHE_TILE}")
print(f"   Preserve zero background: {PRESERVE_ZERO_BACKGROUND} (threshold={BACKGROUND_ZERO_THRESHOLD})")
print(f"   Denoising  : {DENOISE_METHOD} (r={DENOISE_R}, beta={DENOISE_BETA})")
if DENOISE_METHOD == "nlmeans":
    print(f"     NL-Means : h={NLMEANS_H}, template={NLMEANS_TEMPLATE}, search={NLMEANS_SEARCH}")
print(f"   Output width: {OUTPUT_WIDTH}")
if HAS_CUPY:
    print(f"\n   GPU: {cp.cuda.runtime.getDeviceProperties(0)['name'].decode()}")
else:
    print("\n   GPU: not available (running on CPU with NumPy fallback)")
# Out:
# Step 0b: Imports & Configuration loaded
#    Projection : datacitra/Data_mentah/3-WWI-03B_Thorax_PA 3-WWI-03B 90kV40mA0,50s -8_7_2024-9.47 AM [Administrator].mdn
#    Gain       : datacitra/Gain/Trx/90_40_0,50.mdn
#    Dark       : datacitra/Dark/Trx/dark.mdn
#    Calibration: datacitra/Kalibrasi/trx_44_35.npz
#    FFC median : 7
#    Decomp.    : fabemd
#    BEMD       : max_iter=1, threshold=1.0, window=32, extrema=10
#    FABEMD     : max_sift=1, sd=0.2, min_ext=5, max_bimfs=20, win_cap=2000, initial=None, growth=2
#    Homomorphic: gaussian (D0=40, Rh=2.5, Rl=0.99)
#    Enhancement: gamma=0.8, CLAHE clip=3.0, tile=(8, 8)
#    Preserve zero background: True (threshold=0.0)
#    Denoising  : nlmeans (r=1, beta=1)
#      NL-Means : h=10.0, template=7, search=21
#    Output width: 4096
#
#    GPU: not available (running on CPU with NumPy fallback)

# %%
# ============================================================
# Step 0c: Export Setup (Auto-save stages and figures)
# ============================================================
from pathlib import Path
from datetime import datetime
import json

RUN_TAG = datetime.now().strftime("%Y%m%d_%H%M%S")
EXPORT_ROOT = Path("output") / "playground_exports" / RUN_TAG
STAGE_DIR = EXPORT_ROOT / "stages"
FIG_DIR = EXPORT_ROOT / "figures"
METRIC_DIR = EXPORT_ROOT / "metrics"
for _d in (STAGE_DIR, FIG_DIR, METRIC_DIR):
    _d.mkdir(parents=True, exist_ok=True)

def save_stage_image(name, img):
    """Save image-like array to 16-bit TIFF inside stage folder."""
    arr = _to_numpy(img).astype(np.float32)
    vmin, vmax = float(arr.min()), float(arr.max())
    if vmax > vmin:
        arr = (arr - vmin) / (vmax - vmin)
    else:
        arr = np.zeros_like(arr)
    out = (arr * 65535.0).astype(np.uint16)
    out_path = STAGE_DIR / f"{name}.tiff"
    cv2.imwrite(str(out_path), out)
    print(f"Saved stage image: {out_path}")
    return out_path

def get_background_mask(reference, threshold=0.0):
    """Build a mask for invalid background pixels from the calibrated reference."""
    ref = _to_numpy(reference)
    mask = ref <= threshold if threshold > 0 else ref == 0
    return mask if np.any(mask) else None

def zero_background(img, mask):
    """Force masked background pixels to zero without mutating the input."""
    if mask is None:
        return img
    out = np.array(_to_numpy(img), copy=True)
    out[mask] = 0
    return out

def print_background_stats(name, img, mask):
    """Print background statistics for the preserved calibrated mask."""
    if mask is None:
        print(f"   {name} background: no zero-background mask")
        return
    vals = _to_numpy(img)[mask]
    print(
        f"   {name} background: min={vals.min():.6g}, max={vals.max():.6g}, "
        f"mean={vals.mean():.6g}, p99={np.percentile(vals, 99):.6g}"
    )

_original_plt_show = plt.show
_figure_counter = 0

def _autosave_show(*args, **kwargs):
    global _figure_counter
    fig = plt.gcf()
    _figure_counter += 1
    fig_path = FIG_DIR / f"figure_{_figure_counter:03d}.png"
    fig.savefig(str(fig_path), dpi=200, bbox_inches="tight")
    print(f"Saved figure: {fig_path}")
    return _original_plt_show(*args, **kwargs)

plt.show = _autosave_show

print("Step 0c: Export setup ready")
print(f"   Export root : {EXPORT_ROOT}")
print(f"   Stage dir   : {STAGE_DIR}")
print(f"   Figure dir  : {FIG_DIR}")
print(f"   Metrics dir : {METRIC_DIR}")
# Out:
# Step 0c: Export setup ready
#    Export root : output\playground_exports\20260615_233214
#    Stage dir   : output\playground_exports\20260615_233214\stages
#    Figure dir  : output\playground_exports\20260615_233214\figures
#    Metrics dir : output\playground_exports\20260615_233214\metrics

# %% [markdown]
# ## Step 1: Load Images
#
# Load the three images required for Flat Field Correction:
# - **Projection image** (`PROJ_IMG_PATH`) — the raw X-ray capture from the detector. Contains the patient anatomy plus detector artifacts and illumination non-uniformity.
# - **Gain image** (`GAIN_IMG_PATH`) — captured with uniform X-ray illumination (no patient). Records per-pixel detector sensitivity. Used to normalize brightness.
# - **Dark image** (`DARK_IMG_PATH`) — captured with no illumination (shutter closed). Records electronic noise / dark current. Subtracted from both projection and gain.
#
# > **Colab tip:** If your files are on Google Drive, set paths like `f"{DRIVE_ROOT}/your_folder/file.mdn"` in Step 0b.
# > Or use the upload widget below (set `USE_UPLOAD = True`).

# %%
# ============================================================
# Step 1: Load Images (Projection, Gain, Dark)
# ============================================================
USE_UPLOAD = False  # Set True on Colab to upload files interactively

if IS_COLAB and USE_UPLOAD:
    from google.colab import files
    print("Upload your PROJECTION image:")
    up = files.upload()
    PROJ_IMG_PATH = list(up.keys())[0]

    print("Upload your GAIN image:")
    up = files.upload()
    GAIN_IMG_PATH = list(up.keys())[0]

    print("Upload your DARK image:")
    up = files.upload()
    DARK_IMG_PATH = list(up.keys())[0]

proj_image = cv2.imread(PROJ_IMG_PATH, cv2.IMREAD_UNCHANGED)
gain_image = cv2.imread(GAIN_IMG_PATH, cv2.IMREAD_UNCHANGED)
dark_image = cv2.imread(DARK_IMG_PATH, cv2.IMREAD_UNCHANGED)

for name, img, path in [("Projection", proj_image, PROJ_IMG_PATH),
                         ("Gain", gain_image, GAIN_IMG_PATH),
                         ("Dark", dark_image, DARK_IMG_PATH)]:
    if img is None:
        raise FileNotFoundError(f"Could not load {name} image: {path}")

print("Step 1: All images loaded successfully")
for name, img in [("Projection", proj_image), ("Gain", gain_image), ("Dark", dark_image)]:
    print(f"   {name:12s}: shape={img.shape}, dtype={img.dtype}, "
          f"min={img.min()}, max={img.max()}, mean={img.mean():.2f}")

save_stage_image("01_projection_raw", proj_image)
save_stage_image("01_gain_raw", gain_image)
save_stage_image("01_dark_raw", dark_image)

# Display all three images
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
for ax, (title, img) in zip(axes, [("Projection", proj_image),
                                     ("Gain", gain_image),
                                     ("Dark", dark_image)]):
    ax.imshow(img, cmap='gray')
    ax.set_title(f'{title} ({img.shape[1]}x{img.shape[0]})')
    ax.axis('off')

plt.suptitle('Step 1: Loaded Images', fontsize=14)
plt.tight_layout()
plt.show()

# Histograms
fig, axes = plt.subplots(1, 3, figsize=(18, 3))
for ax, (title, img, color) in zip(axes, [("Projection", proj_image, 'steelblue'),
                                           ("Gain", gain_image, 'coral'),
                                           ("Dark", dark_image, 'seagreen')]):
    ax.hist(img.ravel(), bins=256, color=color, alpha=0.7)
    ax.set_title(f'{title} Histogram')
    ax.set_xlabel('Pixel Intensity')

plt.suptitle('Step 1: Image Histograms', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# Step 1: All images loaded successfully
#    Projection  : shape=(3000, 4096), dtype=uint16, min=0, max=768, mean=188.52
#    Gain        : shape=(3000, 4096), dtype=uint16, min=0, max=1222, mean=619.54
#    Dark        : shape=(3000, 4096), dtype=uint16, min=0, max=72, mean=0.04
# Saved stage image: output\playground_exports\20260615_233214\stages\01_projection_raw.tiff
# Saved stage image: output\playground_exports\20260615_233214\stages\01_gain_raw.tiff
# Saved stage image: output\playground_exports\20260615_233214\stages\01_dark_raw.tiff
# Saved figure: output\playground_exports\20260615_233214\figures\figure_001.png
# Saved figure: output\playground_exports\20260615_233214\figures\figure_002.png

# %% [markdown]
# ## Step 2: Flat Field Correction (FFC)
#
# FFC removes detector non-uniformity using the formula:
#
# $$\mu = -\ln\!\left(\frac{I_{proj} - I_{dark}}{I_{gain} - I_{dark}}\right)$$
#
# Images are normalized to [0, 1], the gain image is median-filtered (kernel size = `FFC_MEDIAN_SIZE`) to remove hot/dead pixels, then the correction is computed on GPU.
#
# **Key parameter:**
# - `FFC_MEDIAN_SIZE` (default **7**): odd-integer kernel for median filtering the gain image. Larger values smooth more detector artifacts but may slightly blur. Typical range: 3–11.

# %%
# ============================================================
# Step 2: Flat Field Correction (FFC)
# ============================================================
ffc = FlatFieldCorrection(median_filter_size=FFC_MEDIAN_SIZE)
ffc_image_gpu = ffc.apply(proj_image, gain_image, dark_image)

# Bring back to CPU for display
ffc_image = _to_numpy(ffc_image_gpu)

print("Step 2: Flat Field Correction completed")
print(f"   Median filter size: {FFC_MEDIAN_SIZE}")
print(f"   Output shape: {ffc_image.shape}")
print(f"   Output dtype: {ffc_image.dtype}")
print(f"   Min: {ffc_image.min():.6f}, Max: {ffc_image.max():.6f}, Mean: {ffc_image.mean():.6f}")
save_stage_image("02_ffc", ffc_image)

# Display projection vs FFC result
fig, axes = plt.subplots(1, 2, figsize=(14, 6))
axes[0].imshow(proj_image, cmap='gray')
axes[0].set_title('Raw Projection')
axes[0].axis('off')

axes[1].imshow(ffc_image, cmap='gray')
axes[1].set_title('After Flat Field Correction')
axes[1].axis('off')

plt.suptitle('Step 2: Flat Field Correction', fontsize=14)
plt.tight_layout()
plt.show()

# Histogram
fig, axes = plt.subplots(1, 2, figsize=(14, 3))
axes[0].hist(proj_image.ravel(), bins=256, color='steelblue', alpha=0.7)
axes[0].set_title('Raw Projection Histogram')
axes[0].set_xlabel('Pixel Intensity')

axes[1].hist(ffc_image.ravel(), bins=256, color='coral', alpha=0.7)
axes[1].set_title('FFC Result Histogram')
axes[1].set_xlabel('Pixel Intensity')

plt.suptitle('Step 2: Histogram Before/After FFC', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# 2026-06-15 23:32:27,554 - INFO - Applying Flat Field Correction...
# 2026-06-15 23:32:42,929 - INFO - Flat Field Correction completed.
# Step 2: Flat Field Correction completed
#    Median filter size: 7
#    Output shape: (3000, 4096)
#    Output dtype: float32
#    Min: 0.000000, Max: 3.091043, Mean: 1.273860
# Saved stage image: output\playground_exports\20260615_233214\stages\02_ffc.tiff
# Saved figure: output\playground_exports\20260615_233214\figures\figure_003.png
# Saved figure: output\playground_exports\20260615_233214\figures\figure_004.png

# %% [markdown]
# ## Step 3: Spatial Calibration
#
# Corrects lens distortion using camera matrix and distortion coefficients from a pre-computed calibration file (.npz). The image is undistorted and cropped to the valid region of interest (ROI).
#
# **Key parameter:**
# - `CALIB_PATH`: path to the `.npz` file generated from checkerboard calibration. Contains `camera_matrix`, `dist_coeffs`, and `roi`.

# %%
# ============================================================
# Step 3: Spatial Calibration
# ============================================================
calibrator = SpatialCalibration(CALIB_PATH)
calibrated_image = calibrator.apply(ffc_image_gpu)
background_mask = get_background_mask(calibrated_image, BACKGROUND_ZERO_THRESHOLD) if PRESERVE_ZERO_BACKGROUND else None

print("Step 3: Spatial Calibration completed")
print(f"   Calibration file: {CALIB_PATH}")
print(f"   Before: {ffc_image.shape}")
print(f"   After : {calibrated_image.shape}")
print(f"   Dtype : {calibrated_image.dtype}")
print(f"   Min: {calibrated_image.min():.6f}, Max: {calibrated_image.max():.6f}, Mean: {calibrated_image.mean():.6f}")
print(f"   ROI   : {calibrator.roi}")
if background_mask is not None:
    print(f"   Background mask: {int(background_mask.sum())} pixels <= {BACKGROUND_ZERO_THRESHOLD}")
    print_background_stats("Calibrated", calibrated_image, background_mask)
else:
    print("   Background mask: disabled or empty")
save_stage_image("03_calibrated", calibrated_image)
background_mask_display = (
    background_mask.astype(np.uint8)
    if background_mask is not None
    else np.zeros_like(calibrated_image, dtype=np.uint8)
)
save_stage_image("03_background_mask", background_mask_display)

# Display FFC vs Calibrated vs Background Mask
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
axes[0].imshow(ffc_image, cmap='gray')
axes[0].set_title(f'FFC Result ({ffc_image.shape[1]}x{ffc_image.shape[0]})')
axes[0].axis('off')

axes[1].imshow(calibrated_image, cmap='gray')
axes[1].set_title(f'Calibrated & Cropped ({calibrated_image.shape[1]}x{calibrated_image.shape[0]})')
axes[1].axis('off')

mask_pixels = int(background_mask_display.sum())
mask_percent = 100.0 * background_mask_display.mean()
axes[2].imshow(background_mask_display, cmap='gray', vmin=0, vmax=1)
axes[2].set_title(f'Background Mask\n{mask_pixels} pixels ({mask_percent:.2f}%)')
axes[2].axis('off')

plt.suptitle('Step 3: Spatial Calibration', fontsize=14)
plt.tight_layout()
plt.show()

# --- Histogram of Spatial Calibrated Image ---
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Linear-scale histogram
axes[0].hist(calibrated_image.ravel(), bins=512, color='steelblue', alpha=0.8, edgecolor='none')
axes[0].set_title('Calibrated Image Histogram (Linear)', fontsize=12)
axes[0].set_xlabel('Pixel Intensity')
axes[0].set_ylabel('Frequency')
axes[0].axvline(x=calibrated_image.mean(), color='red', linestyle='--', linewidth=1.5,
                label=f'Mean = {calibrated_image.mean():.4f}')
axes[0].axvline(x=np.median(calibrated_image), color='orange', linestyle='--', linewidth=1.5,
                label=f'Median = {np.median(calibrated_image):.4f}')
axes[0].legend(fontsize=9)

# Log-scale histogram (shows tail detail)
axes[1].hist(calibrated_image.ravel(), bins=512, color='coral', alpha=0.8, edgecolor='none')
axes[1].set_yscale('log')
axes[1].set_title('Calibrated Image Histogram (Log Scale)', fontsize=12)
axes[1].set_xlabel('Pixel Intensity')
axes[1].set_ylabel('Frequency (log)')
axes[1].axvline(x=calibrated_image.mean(), color='red', linestyle='--', linewidth=1.5,
                label=f'Mean = {calibrated_image.mean():.4f}')
axes[1].legend(fontsize=9)

plt.suptitle('Step 3: Spatial Calibration — Histogram', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# 2026-06-15 23:32:51,425 - INFO - Applying Spatial Calibration...
# 2026-06-15 23:32:51,598 - INFO - Spatial Calibration completed.
# Step 3: Spatial Calibration completed
#    Calibration file: datacitra/Kalibrasi/trx_44_35.npz
#    Before: (3000, 4096)
#    After : (2959, 3685)
#    Dtype : float32
#    Min: 0.000000, Max: 2.496468, Mean: 1.308815
#    ROI   : [ 220    0 3685 3000]
#    Background mask: 531336 pixels <= 0.0
#    Calibrated background: min=0, max=0, mean=0, p99=0
# Saved stage image: output\playground_exports\20260615_233214\stages\03_calibrated.tiff
# Saved stage image: output\playground_exports\20260615_233214\stages\03_background_mask.tiff
# Saved figure: output\playground_exports\20260615_233214\figures\figure_005.png
# Saved figure: output\playground_exports\20260615_233214\figures\figure_006.png

# %% [markdown]
# ## Step 4: Decomposition (BEMD / FABEMD)
#
# Bidimensional Empirical Mode Decomposition extracts **BIMFs** (Bidimensional Intrinsic Mode Functions) from the calibrated image. Each BIMF captures oscillations at a different spatial scale; the residue holds the smooth background trend.
#
# | Method | Description |
# |--------|-------------|
# | **BEMD** | Classic iterative sifting with surface interpolation |
# | **FABEMD** | Fast & Adaptive (Bhuiyan et al. 2008) — adaptive windows + order-statistics filters |
#
# The method is selected by `DECOMPOSITION_METHOD` in Step 0b. Both produce `bimfs` (list of 2D arrays) and `energies` (per-BIMF energy, used later to select which BIMFs to denoise).
#
# **BEMD parameters:**
# - `BEMD_MAX_ITER` (**1**): max sifting iterations per BIMF. More = finer BIMFs but slower.
# - `BEMD_THRESHOLD` (**1.0**): SD convergence threshold. Lower = stricter.
# - `BEMD_WINDOW_SIZE` (**32**): initial window (px) for extrema detection.
# - `BEMD_EXTREMA_COUNT` (**10**): min extrema to continue. Higher stops earlier.
#
# **FABEMD parameters** *(Bhuiyan et al. 2008; Siracusano et al. 2020)*:
# - `FABEMD_MAX_SIFT` (**1**): MNAI — max sifting iterations per BIMF. Paper: "limiting to one is sufficient".
# - `FABEMD_SD_THRESH` (**0.2**): SD stopping criterion. Secondary with MNAI=1.
# - `FABEMD_MIN_EXTREMA` (**5**): min extrema to keep extracting. Lower = more BIMFs.
# - `FABEMD_MAX_BIMFS` (**20**): hard cap on total BIMFs. PACE paper shows ~9 for CXR.
# - `FABEMD_WIN_CAP` (**2000**): max window size for order-statistics filters.
# - `FABEMD_EXTREMA_WIN` (**3**): 3x3 window for extrema detection. Paper: "3x3 results in optimum extrema maps".
# - `FABEMD_INITIAL_WINDOW` (**None**): starting window floor. `None` keeps the first window adaptive; an integer such as `32` sets the initial floor after odd/clamp normalization.
# - `FABEMD_GROWTH_RATE` (**2**): max window growth factor per BIMF. Controls gradual scaling from fine edges to coarse contrast. Lower = more intermediate BIMFs.

# %%
# ============================================================
# Step 4: Decomposition (BEMD or FABEMD)
# ============================================================
image_gpu = cp.asarray(calibrated_image.astype(np.float64))
print(f"Step 4: Running {DECOMPOSITION_METHOD.upper()} decomposition...")
print(f"   Input shape: {image_gpu.shape}, dtype: {image_gpu.dtype}")

residue = None          # only set by FABEMD
entropies = None        # only set by FABEMD

if DECOMPOSITION_METHOD == "fabemd":
    decomposer = FABEMD(
        max_sift_iterations=FABEMD_MAX_SIFT,
        sd_threshold=FABEMD_SD_THRESH,
        min_extrema=FABEMD_MIN_EXTREMA,
        max_bimfs=FABEMD_MAX_BIMFS,
        window_size_cap=FABEMD_WIN_CAP,
        extrema_window=FABEMD_EXTREMA_WIN,
        initial_window_size=FABEMD_INITIAL_WINDOW,
        window_growth_rate=FABEMD_GROWTH_RATE,
    )
    bimfs, residue = decomposer.decompose_with_residual(image_gpu)
    energies   = FABEMD.calculate_energies(bimfs)
    entropies  = FABEMD.calculate_all_entropies(bimfs)
    residue_entropy = FABEMD.calculate_entropy(residue)
else:
    decomposer = BEMD(
        max_iterations=BEMD_MAX_ITER,
        threshold=BEMD_THRESHOLD,
        initial_window_size=BEMD_WINDOW_SIZE,
        local_extrema_count=BEMD_EXTREMA_COUNT,
    )
    bimfs    = decomposer.decompose(image_gpu)
    energies = BEMD.calculate_energies(bimfs)

# ---------- Print results ----------
n_bimfs = len(bimfs)
print(f"\nStep 4: {DECOMPOSITION_METHOD.upper()} completed -- {n_bimfs} BIMFs extracted")

if DECOMPOSITION_METHOD == "fabemd":
    # Show adaptive window progression
    if hasattr(decomposer, 'window_sizes_') and decomposer.window_sizes_:
        print(f"\n   Window size progression (upper/lower):")
        for i, (wu, wl) in enumerate(decomposer.window_sizes_):
            print(f"     BIMF {i}: w_upper={wu}, w_lower={wl}")

    print(f"\n   {'BIMF':>6} {'Energy':>14} {'Entropy (nats)':>16}")
    print(f"   {'-'*38}")
    for i, (eng, ent) in enumerate(zip(energies, entropies)):
        print(f"   {i:>6} {eng:>14.4f} {ent:>16.4f}")
    print(f"   {'Res.':>6} {'--':>14} {residue_entropy:>16.4f}")
else:
    for i, (bimf, eng) in enumerate(zip(bimfs, energies)):
        bimf_np = _to_numpy(bimf)
        print(f"   BIMF {i}: energy={eng:.4f}, min={bimf_np.min():.4f}, max={bimf_np.max():.4f}")

for i, bimf in enumerate(bimfs):
    save_stage_image(f"04_bimf_{i:02d}", _to_numpy(bimf))
if residue is not None:
    save_stage_image("04_residue", _to_numpy(residue))
    print_background_stats("Residue", _to_numpy(residue), background_mask)
# Out:
# 2026-06-15 23:33:03,788 - INFO - Starting FABEMD decomposition...
# Step 4: Running FABEMD decomposition...
#    Input shape: (2959, 3685), dtype: float64
# FABEMD: 8 BIMFs | window=1023 | residual extrema: 7508
# 2026-06-15 23:33:29,628 - INFO - Stopping: residual has ≤ 5 extrema (2).
# 2026-06-15 23:33:29,629 - INFO - FABEMD decomposition completed — 9 BIMFs extracted.
# FABEMD: 9 BIMFs | window=2001 | residual extrema: 2
#
# Step 4: FABEMD completed -- 9 BIMFs extracted
#
#    Window size progression (upper/lower):
#      BIMF 0: w_upper=7, w_lower=7
#      BIMF 1: w_upper=15, w_lower=15
#      BIMF 2: w_upper=31, w_lower=31
#      BIMF 3: w_upper=63, w_lower=63
#      BIMF 4: w_upper=127, w_lower=127
#      BIMF 5: w_upper=255, w_lower=255
#      BIMF 6: w_upper=511, w_lower=511
#      BIMF 7: w_upper=1023, w_lower=1023
#      BIMF 8: w_upper=2001, w_lower=2001
#
#      BIMF         Energy   Entropy (nats)
#    --------------------------------------
# ...

# %%
# ============================================================
# Step 4 (cont.): Visualise BIMFs (+ Residue if FABEMD)
# ============================================================
has_residue = residue is not None
total_panels = n_bimfs + (2 if has_residue else 0)   # +original +residue when FABEMD
cols = min(total_panels if has_residue else n_bimfs, 4)
rows = (max(total_panels, n_bimfs) + cols - 1) // cols

fig, axes = plt.subplots(rows, cols, figsize=(5 * cols, 5 * rows))
axes = np.atleast_2d(axes)
all_ax = axes.ravel()

idx = 0
# Show original image when FABEMD (adds context for the residue)
if has_residue:
    all_ax[idx].imshow(calibrated_image, cmap='gray')
    all_ax[idx].set_title('Original (Calibrated)', fontsize=10)
    all_ax[idx].axis('off')
    idx += 1

# BIMFs
for i, bimf in enumerate(bimfs):
    bimf_np = _to_numpy(bimf)
    label = f'BIMF {i}\nE={energies[i]:.1f}'
    if entropies is not None:
        label += f'  H={entropies[i]:.2f}'
    all_ax[idx].imshow(bimf_np, cmap='gray')
    all_ax[idx].set_title(label, fontsize=9)
    all_ax[idx].axis('off')
    idx += 1

# Residue (FABEMD only)
if has_residue:
    all_ax[idx].imshow(_to_numpy(residue), cmap='gray')
    all_ax[idx].set_title(f'Residue\nH={residue_entropy:.2f}', fontsize=10)
    all_ax[idx].axis('off')
    idx += 1

for j in range(idx, len(all_ax)):
    all_ax[j].axis('off')

plt.suptitle(f'Step 4: {DECOMPOSITION_METHOD.upper()} — Extracted BIMFs', fontsize=14)
plt.tight_layout()
plt.show()

# --- Energy (+ Entropy) bar charts ---
x = np.arange(n_bimfs)
if entropies is not None:
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 4))
    ax1.bar(x, energies, color='coral')
    ax1.set_yscale('log')
    ax1.set_xlabel('BIMF Index'); ax1.set_ylabel('Log Energy')
    ax1.set_title(f'{DECOMPOSITION_METHOD.upper()} — BIMF Energies'); ax1.set_xticks(x)

    ax2.bar(x, entropies, color='steelblue')
    ax2.axhline(y=residue_entropy, color='red', ls='--', label=f'Residue ({residue_entropy:.2f})')
    ax2.set_xlabel('BIMF Index'); ax2.set_ylabel('Shannon Entropy (nats)')
    ax2.set_title(f'{DECOMPOSITION_METHOD.upper()} — BIMF Entropies'); ax2.set_xticks(x)
    ax2.legend()
else:
    fig, ax1 = plt.subplots(1, 1, figsize=(8, 3))
    ax1.bar(x, energies, color='coral')
    ax1.set_yscale('log')
    ax1.set_xlabel('BIMF Index'); ax1.set_ylabel('Log Energy')
    ax1.set_title(f'{DECOMPOSITION_METHOD.upper()} — BIMF Energies'); ax1.set_xticks(x)

plt.suptitle(f'Step 4: {DECOMPOSITION_METHOD.upper()} Energy & Entropy', fontsize=14, y=1.02)
plt.tight_layout()
plt.show()
# Out:
# Saved figure: output\playground_exports\20260615_233214\figures\figure_007.png
# Saved figure: output\playground_exports\20260615_233214\figures\figure_008.png

# %% [markdown]
# ## Step 5: Homomorphic Filtering (on Residue)
#
# Homomorphic filtering is applied to the **decomposition residue** to produce homogeneous lighting. The process:
# 1. Take log of the residue (converts multiplicative illumination/reflectance to additive)
# 2. Apply FFT to move into frequency domain
# 3. Apply emphasis filter — suppresses low frequencies (illumination) with gain γ_L, boosts high frequencies (detail) with gain γ_H
# 4. Apply IFFT and exponentiate to return to spatial domain
#
# Two filter shapes are available (`HOMOMORPHIC_METHOD`):
# - **Gaussian** (classic): smooth transition around cutoff D₀
# - **Butterworth** (PACE, Siracusano et al. 2020): sharper roll-off controlled by order n
#
# The filtered residue is combined with denoised BIMFs in Step 6.
#
# > For BEMD (which has no explicit residue), the calibrated image is used as the residue.
#
# **Key parameters:**
# - `D0` (**30**): cutoff frequency in pixels. Lower = more illumination flattening. Range: 10–80.
# - `RH` / `PACE_GAMMA_H` (**2.0** / **1.5**): high-frequency gain (γ_H). >1 amplifies detail. Range: 1.2–3.0.
# - `RL` / `PACE_GAMMA_L` (**0.5** / **0.99**): low-frequency gain (γ_L). <1 suppresses illumination. Range: 0.1–1.0.
# - `PACE_BW_ORDER` (**2**): Butterworth filter order. Higher = sharper cutoff. Range: 1–4.

# %%
# ============================================================
# Step 5: Homomorphic Filtering (on Residue)
# ============================================================

# Determine the residue to filter
# FABEMD produces an explicit residue; BEMD does not, so fall back to calibrated image
if residue is not None:
    residue_input = _to_numpy(residue)
    residue_source = "FABEMD residue"
else:
    residue_input = calibrated_image.copy()
    residue_source = "calibrated image (BEMD — no explicit residue)"

# Build the homomorphic filter
if HOMOMORPHIC_METHOD == "butterworth":
    hf = PACEHomomorphicFilter(d0=D0, gamma_h=PACE_GAMMA_H, gamma_l=PACE_GAMMA_L, n=PACE_BW_ORDER)
    hf_label = f"Butterworth (D0={D0}, γH={PACE_GAMMA_H}, γL={PACE_GAMMA_L}, n={PACE_BW_ORDER})"
else:
    hf = HomomorphicFilter(d0=D0, rh=RH, rl=RL)
    hf_label = f"Gaussian (D0={D0}, Rh={RH}, Rl={RL})"

filtered_residue = hf.apply(residue_input, normalize=False)

print(f"Step 5: Homomorphic Filter applied — {HOMOMORPHIC_METHOD}")
print(f"   Input        : {residue_source}")
print(f"   {hf_label}")
print("   Scale        : raw filtered scale for reconstruction (stage TIFF is display-normalized)")
print(f"   Output shape : {filtered_residue.shape}")
print(f"   Output dtype : {filtered_residue.dtype}")
print(f"   Min: {filtered_residue.min():.4f}, Max: {filtered_residue.max():.4f}, Mean: {filtered_residue.mean():.4f}")
print_background_stats("Residue input", residue_input, background_mask)
print_background_stats("Filtered residue", filtered_residue, background_mask)
save_stage_image("05_residue_input", residue_input)
save_stage_image("05_filtered_residue", filtered_residue)

# Display residue vs filtered residue
fig, axes = plt.subplots(1, 2, figsize=(14, 6))
axes[0].imshow(residue_input, cmap='gray')
axes[0].set_title(f'Residue\n({residue_source})')
axes[0].axis('off')

axes[1].imshow(filtered_residue, cmap='gray')
axes[1].set_title(f'Homomorphic Filtered Residue\n{hf_label}')
axes[1].axis('off')

plt.suptitle('Step 5: Homomorphic Filtering (Residue)', fontsize=14)
plt.tight_layout()
plt.show()

# Histogram comparison
fig, axes = plt.subplots(1, 2, figsize=(14, 3))
axes[0].hist(residue_input.ravel(), bins=256, color='steelblue', alpha=0.7)
axes[0].set_title('Residue Histogram')
axes[0].set_xlabel('Pixel Intensity')

axes[1].hist(filtered_residue.ravel(), bins=256, color='coral', alpha=0.7)
axes[1].set_title('Filtered Residue Histogram')
axes[1].set_xlabel('Pixel Intensity')

plt.suptitle('Step 5: Histogram Comparison', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# Step 5: Homomorphic Filter applied — gaussian
#    Input        : FABEMD residue
#    Gaussian (D0=40, Rh=2.5, Rl=0.99)
#    Scale        : raw filtered scale for reconstruction (stage TIFF is display-normalized)
#    Output shape : (2959, 3685)
#    Output dtype : float64
#    Min: 0.9941, Max: 1.9051, Mean: 1.3177
#    Residue input background: min=1.16941, max=1.52187, mean=1.27142, p99=1.52179
#    Filtered residue background: min=0.994136, max=1.9051, mean=1.25939, p99=1.61541
# Saved stage image: output\playground_exports\20260615_233214\stages\05_residue_input.tiff
# Saved stage image: output\playground_exports\20260615_233214\stages\05_filtered_residue.tiff
# Saved figure: output\playground_exports\20260615_233214\figures\figure_009.png
# Saved figure: output\playground_exports\20260615_233214\figures\figure_010.png

# %% [markdown]
# ## Step 6: Nonlinear Filtering & Reconstruction (Before / After NL-Means)
#
# This step shows the **detailed reconstruction process**:
#
# 1. **Sort BIMFs by energy** (lowest first) — the R lowest-energy components are denoised
# 2. **Denoise** each of the R lowest-energy BIMFs with NL-Means (or bilateral)
# 3. **Reconstruct**: $I_{out} = \sum_{i} \text{BIMF}_i^{*} + \beta \times \text{filtered\_residue}$
#
# We explicitly show:
# - Each BIMF **before** and **after** denoising (side-by-side)
# - The reconstruction formula components
# - The final reconstructed image vs the calibrated reference

# %%
# ============================================================
# Step 6: Nonlinear Filtering & Reconstruction — Before/After NL-Means
# ============================================================

# --- Sort BIMFs by energy ---
sorted_indices = np.argsort(energies)
print(f"Step 6: BIMFs sorted by energy (lowest first): {sorted_indices.tolist()}")
print(f"   Energies (sorted): {[energies[i] for i in sorted_indices]}")
print(f"   Denoise R={DENOISE_R} lowest-energy BIMFs, β={DENOISE_BETA}")
print(f"   Method: {DENOISE_METHOD}\n")

# --- Denoise each of the R lowest-energy BIMFs and show before/after ---
denoised_bimf_list = []

fig, axes = plt.subplots(DENOISE_R, 3, figsize=(18, 5 * DENOISE_R))
if DENOISE_R == 1:
    axes = axes[np.newaxis, :]  # ensure 2D indexing

for i in range(DENOISE_R):
    idx = sorted_indices[i]
    bimf_original = _to_numpy(bimfs[idx]).astype(np.float32)

    # Apply NL-Means or bilateral denoising
    if DENOISE_METHOD == "nlmeans":
        # Scale to uint8 for cv2 NL-Means
        vmin_b, vmax_b = bimf_original.min(), bimf_original.max()
        denom_b = vmax_b - vmin_b if vmax_b != vmin_b else 1.0
        bimf_u8 = np.uint8(np.clip((bimf_original - vmin_b) / denom_b * 255, 0, 255))
        denoised_u8 = cv2.fastNlMeansDenoising(
            bimf_u8, None, h=NLMEANS_H,
            templateWindowSize=NLMEANS_TEMPLATE, searchWindowSize=NLMEANS_SEARCH)
        bimf_denoised = denoised_u8.astype(np.float32) / 255.0 * denom_b + vmin_b
        denoise_tag = f"NL-Means (h={NLMEANS_H})"
    else:
        bimf_denoised = cv2.bilateralFilter(bimf_original, 5, 75, 75)
        denoise_tag = "Bilateral"

    denoised_bimf_list.append(bimf_denoised)

    # Difference map
    diff = np.abs(bimf_original - bimf_denoised)

    # Plot: Before | After | Difference
    axes[i, 0].imshow(bimf_original, cmap='gray')
    axes[i, 0].set_title(f'BIMF {idx} — Before\n(E={energies[idx]:.1f})', fontsize=11)
    axes[i, 0].axis('off')

    axes[i, 1].imshow(bimf_denoised, cmap='gray')
    axes[i, 1].set_title(f'BIMF {idx} — After {denoise_tag}', fontsize=11)
    axes[i, 1].axis('off')

    axes[i, 2].imshow(diff, cmap='hot')
    axes[i, 2].set_title(f'|Difference|\nmax={diff.max():.4f}', fontsize=11)
    axes[i, 2].axis('off')

    print(f"   BIMF {idx}: before std={bimf_original.std():.4f}, after std={bimf_denoised.std():.4f}, "
          f"noise removed (max diff)={diff.max():.4f}")

plt.suptitle(f'Step 6: Before / After {DENOISE_METHOD} Denoising (R={DENOISE_R} lowest-energy BIMFs)', fontsize=14)
plt.tight_layout()
plt.show()

# --- Reconstruction Process ---
print(f"\n   Reconstruction formula:")
print(f"     I_out = Σ BIMF_i* + β × filtered_residue  (β={DENOISE_BETA})")

# Sum denoised BIMFs (R lowest-energy)
I_denoised = np.sum(denoised_bimf_list, axis=0)

# Sum remaining original BIMFs
I_original = np.zeros_like(I_denoised)
for j in range(DENOISE_R, len(bimfs)):
    idx = sorted_indices[j]
    I_original += _to_numpy(bimfs[idx])

# Weighted residue
I_residue = DENOISE_BETA * filtered_residue

# Full reconstruction
denoised_image = I_denoised + I_original + I_residue

print(f"     Σ denoised BIMFs : mean={I_denoised.mean():.4f}, std={I_denoised.std():.4f}")
print(f"     Σ original BIMFs : mean={I_original.mean():.4f}, std={I_original.std():.4f}")
print(f"     β × residue      : mean={I_residue.mean():.4f}, std={I_residue.std():.4f}")
print(f"     I_out             : mean={denoised_image.mean():.4f}, std={denoised_image.std():.4f}")
print_background_stats("Reconstructed", denoised_image, background_mask)

save_stage_image("06_denoised_low_energy_sum", I_denoised)
save_stage_image("06_original_remaining_sum", I_original)
save_stage_image("06_weighted_residue", I_residue)
save_stage_image("06_reconstructed", denoised_image)

# --- Visualise reconstruction components ---
fig, axes = plt.subplots(2, 3, figsize=(18, 11))

axes[0, 0].imshow(calibrated_image, cmap='gray')
axes[0, 0].set_title('Input (Calibrated)', fontsize=11)
axes[0, 0].axis('off')

axes[0, 1].imshow(I_denoised, cmap='gray')
axes[0, 1].set_title(f'Σ Denoised BIMFs\n(R={DENOISE_R} lowest-energy)', fontsize=11)
axes[0, 1].axis('off')

axes[0, 2].imshow(I_original, cmap='gray')
axes[0, 2].set_title(f'Σ Original BIMFs\n(remaining {len(bimfs)-DENOISE_R})', fontsize=11)
axes[0, 2].axis('off')

axes[1, 0].imshow(filtered_residue, cmap='gray')
axes[1, 0].set_title(f'β × Filtered Residue\n(β={DENOISE_BETA})', fontsize=11)
axes[1, 0].axis('off')

axes[1, 1].imshow(denoised_image, cmap='gray')
axes[1, 1].set_title('Reconstructed Image', fontsize=11)
axes[1, 1].axis('off')

# Difference: calibrated vs reconstructed
diff_recon = np.abs(calibrated_image.astype(np.float64) - denoised_image.astype(np.float64))
axes[1, 2].imshow(diff_recon, cmap='hot')
axes[1, 2].set_title(f'|Calibrated − Reconstructed|\nmax diff={diff_recon.max():.4f}', fontsize=11)
axes[1, 2].axis('off')

plt.suptitle('Step 6: Reconstruction Process Breakdown', fontsize=14)
plt.tight_layout()
plt.show()

print(f"\nStep 6: Reconstruction completed")
print(f"   Output shape: {denoised_image.shape}, dtype: {denoised_image.dtype}")
print(f"   Min: {denoised_image.min():.4f}, Max: {denoised_image.max():.4f}, Mean: {denoised_image.mean():.4f}")
# Out:
# Step 6: BIMFs sorted by energy (lowest first): [0, 1, 2, 3, 4, 5, 8, 6, 7]
#    Energies (sorted): [590.0151386071454, 794.8208012812186, 2368.6905261598286, 8581.477710280375, 32256.499640731527, 92906.35454613307, 159926.79598025742, 234479.76854407057, 355482.5520873645]
#    Denoise R=1 lowest-energy BIMFs, β=1
#    Method: nlmeans
#
#    BIMF 0: before std=0.0074, after std=0.0044, noise removed (max diff)=0.0312
# Saved figure: output\playground_exports\20260615_233214\figures\figure_011.png
#    Reconstruction formula:
#      I_out = Σ BIMF_i* + β × filtered_residue  (β=1)
#      Σ denoised BIMFs : mean=-0.0004, std=0.0044
#      Σ original BIMFs : mean=-0.0121, std=0.4898
#      β × residue      : mean=1.3177, std=0.1032
#      I_out             : mean=1.3052, std=0.5029
#    Reconstructed background: min=-0.1932, max=0.382887, mean=-0.0123284, p99=0.116235
# Saved stage image: output\playground_exports\20260615_233214\stages\06_denoised_low_energy_sum.tiff
# ...

# %% [markdown]
# ## Step 7: Gamma Correction
#
# Gamma correction adjusts overall brightness by applying: $I_{out} = I_{in}^{\gamma}$
#
# - **γ < 1**: brightens the image (expands dark tones, compresses highlights) — useful for dark medical X-rays.
# - **γ > 1**: darkens the image.
# - **γ = 1**: no change.
# - This step intentionally keeps the raw gamma output; background masking is applied independently after CLAHE in Step 9.
#
# **Key parameter:** `GAMMA` (**0.8**). Typical range for medical X-rays: 0.5–1.0.

# %%
# ============================================================
# Step 7: Gamma Correction
# ============================================================
gamma_image = ImageEnhancer.gamma_correction(denoised_image, gamma=GAMMA)

print(f"Step 7: Gamma Correction applied (gamma={GAMMA})")
print(f"   Output dtype: {gamma_image.dtype}")
print(f"   Min: {gamma_image.min()}, Max: {gamma_image.max()}, Mean: {gamma_image.mean():.2f}")
print("   Background masking is applied independently after CLAHE in Step 9")
save_stage_image("07_gamma_corrected", gamma_image)

# Display
fig, axes = plt.subplots(1, 2, figsize=(14, 6))
axes[0].imshow(denoised_image, cmap='gray')
axes[0].set_title('Before Gamma Correction')
axes[0].axis('off')

axes[1].imshow(gamma_image, cmap='gray')
axes[1].set_title(f'After Gamma Correction (gamma={GAMMA})')
axes[1].axis('off')

plt.suptitle('Step 7: Gamma Correction', fontsize=14)
plt.tight_layout()
plt.show()

# Histogram comparison
fig, axes = plt.subplots(1, 2, figsize=(14, 3))
axes[0].hist(denoised_image.ravel(), bins=256, color='steelblue', alpha=0.7)
axes[0].set_title('Before Gamma')
axes[0].set_xlabel('Pixel Intensity')

axes[1].hist(gamma_image.ravel(), bins=256, color='coral', alpha=0.7)
axes[1].set_title('After Gamma')
axes[1].set_xlabel('Pixel Intensity')

plt.suptitle('Step 7: Histogram Before/After Gamma', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# Step 7: Gamma Correction applied (gamma=0.8)
#    Output dtype: uint16
#    Min: 0, Max: 65535, Mean: 38883.44
#    Background masking is applied independently after CLAHE in Step 9
# Saved stage image: output\playground_exports\20260615_233214\stages\07_gamma_corrected.tiff
# Saved figure: output\playground_exports\20260615_233214\figures\figure_013.png
# Saved figure: output\playground_exports\20260615_233214\figures\figure_014.png

# %% [markdown]
# ## Step 8: CLAHE Enhancement
#
# **Contrast Limited Adaptive Histogram Equalization** divides the image into tiles and equalizes each independently, enhancing local contrast. A clip limit prevents over-amplification of noise in uniform regions.
#
# **Key parameters:**
# - `CLAHE_CLIP` (**3.0**): maximum contrast amplification per tile. Higher = stronger enhancement but may amplify noise. Range: 1.0–10.0.
# - `CLAHE_TILE` (**(8, 8)**): grid size (rows, cols). More tiles = more local enhancement but may introduce tile-boundary artifacts. Typical: (4,4)–(16,16).
# - This step intentionally keeps the raw CLAHE output; background masking is applied independently in Step 9.

# %%
# ============================================================
# Step 8: CLAHE Enhancement
# ============================================================
clahe_image = ImageEnhancer.apply_clahe(gamma_image, clip_limit=CLAHE_CLIP, tile_grid_size=CLAHE_TILE)

print(f"Step 8: CLAHE applied (clip_limit={CLAHE_CLIP}, tile={CLAHE_TILE})")
print(f"   Output dtype: {clahe_image.dtype}")
print(f"   Min: {clahe_image.min()}, Max: {clahe_image.max()}, Mean: {clahe_image.mean():.2f}")
print("   Background masking is applied independently in Step 9")
save_stage_image("08_clahe", clahe_image)

# Display
fig, axes = plt.subplots(1, 2, figsize=(14, 6))
axes[0].imshow(gamma_image, cmap='gray')
axes[0].set_title('Before CLAHE')
axes[0].axis('off')

axes[1].imshow(clahe_image, cmap='gray')
axes[1].set_title(f'After CLAHE (clip={CLAHE_CLIP}, tile={CLAHE_TILE})')
axes[1].axis('off')

plt.suptitle('Step 8: CLAHE Enhancement', fontsize=14)
plt.tight_layout()
plt.show()

# Histogram comparison
fig, axes = plt.subplots(1, 2, figsize=(14, 3))
axes[0].hist(gamma_image.ravel(), bins=256, color='steelblue', alpha=0.7)
axes[0].set_title('Before CLAHE')
axes[0].set_xlabel('Pixel Intensity')

axes[1].hist(clahe_image.ravel(), bins=256, color='coral', alpha=0.7)
axes[1].set_title('After CLAHE')
axes[1].set_xlabel('Pixel Intensity')

plt.suptitle('Step 8: Histogram Before/After CLAHE', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# Step 8: CLAHE applied (clip_limit=3.0, tile=(8, 8))
#    Output dtype: uint16
#    Min: 2, Max: 65535, Mean: 37328.86
#    Background masking is applied independently in Step 9
# Saved stage image: output\playground_exports\20260615_233214\stages\08_clahe.tiff
# Saved figure: output\playground_exports\20260615_233214\figures\figure_015.png
# Saved figure: output\playground_exports\20260615_233214\figures\figure_016.png

# %% [markdown]
# ## Step 9: Background Masking After CLAHE
#
# Apply the calibrated zero-background mask as its own independent stage. The raw CLAHE output stays available as `clahe_image`, while `masked_clahe_image` becomes the processed image used for metrics, resizing, and export.

# %%
# ============================================================
# Step 9: Background Masking After CLAHE
# ============================================================
masked_clahe_image = zero_background(clahe_image, background_mask)

print("Step 9: Background masking after CLAHE")
if background_mask is not None:
    mask_pixels = int(background_mask.sum())
    mask_percent = 100.0 * background_mask.mean()
    print(f"   Masked pixels: {mask_pixels} ({mask_percent:.2f}%)")
else:
    print("   Background mask: disabled or empty")
print(f"   Output dtype: {masked_clahe_image.dtype}")
print(f"   Min: {masked_clahe_image.min()}, Max: {masked_clahe_image.max()}, Mean: {masked_clahe_image.mean():.2f}")
print_background_stats("Masked CLAHE", masked_clahe_image, background_mask)
save_stage_image("09_masked_clahe", masked_clahe_image)

# Display raw CLAHE vs independently masked CLAHE
fig, axes = plt.subplots(1, 2, figsize=(14, 6))
axes[0].imshow(clahe_image, cmap='gray')
axes[0].set_title('Raw CLAHE')
axes[0].axis('off')

axes[1].imshow(masked_clahe_image, cmap='gray')
axes[1].set_title('Masked CLAHE')
axes[1].axis('off')

plt.suptitle('Step 9: Background Masking After CLAHE', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# Step 9: Background masking after CLAHE
#    Masked pixels: 531336 (4.87%)
#    Output dtype: uint16
#    Min: 0, Max: 65535, Mean: 37022.06
#    Masked CLAHE background: min=0, max=0, mean=0, p99=0
# Saved stage image: output\playground_exports\20260615_233214\stages\09_masked_clahe.tiff
# Saved figure: output\playground_exports\20260615_233214\figures\figure_017.png

# %% [markdown]
# ## Step 10: Comprehensive Image Quality Metrics
#
# Using the **spatial calibrated image** as the reference, we compute:
#
# | Metric | Type | Description |
# |--------|------|-------------|
# | **CII** | Full-reference | Contrast Improvement Index — ratio of processed/reference contrast |
# | **SNR** | No-reference | Signal-to-Noise Ratio — mean / std of signal |
# | **CNR** | No-reference | Contrast-to-Noise Ratio — contrast relative to noise |
# | **Entropy** | No-reference | Shannon entropy — information content (bits/pixel) |
# | **EME** | No-reference | Effective Measure of Enhancement — local contrast across blocks |
# | **BRISQUE** | No-reference | Blind/Referenceless Image Spatial Quality (via `image-quality` or manual NSS) |
# | **SSIM** | Full-reference | Structural Similarity Index — perceptual quality vs reference |

# %%
# ============================================================
# Step 10: Comprehensive Image Quality Metrics
# ============================================================
# Reference = spatial calibrated image (calibrated_image)
# Processed = masked CLAHE-enhanced image (masked_clahe_image)

from skimage.metrics import structural_similarity as ssim

# --- Helper functions for additional metrics ---

def calculate_snr(image):
    """Signal-to-Noise Ratio: mean(signal) / std(signal)."""
    img = image.astype(np.float64)
    signal_mean = img.mean()
    noise_std = img.std()
    if noise_std < 1e-10:
        return float('inf')
    return float(signal_mean / noise_std)

def calculate_cnr(image, block_size=64):
    """Contrast-to-Noise Ratio: (max_block_mean - min_block_mean) / std."""
    img = image.astype(np.float64)
    h, w = img.shape
    bh, bw = block_size, block_size
    means = []
    for i in range(0, h - bh + 1, bh):
        for j in range(0, w - bw + 1, bw):
            block = img[i:i+bh, j:j+bw]
            means.append(block.mean())
    if len(means) < 2:
        return 0.0
    means = np.array(means)
    contrast = means.max() - means.min()
    noise = img.std()
    if noise < 1e-10:
        return float('inf')
    return float(contrast / noise)

def calculate_entropy_generic(image):
    """Shannon entropy (handles any dtype by auto-binning)."""
    img = image.astype(np.float64)
    # Use 256 bins normalised to image range
    hist, _ = np.histogram(img.ravel(), bins=256)
    hist = hist / hist.sum()
    hist = hist[hist > 0]
    return float(-np.sum(hist * np.log2(hist)))

def calculate_brisque_features(image):
    """
    Simplified BRISQUE-like score using Natural Scene Statistics (NSS).
    Computes mean-subtracted contrast-normalised (MSCN) coefficients
    and uses their distribution stats as a quality proxy.
    Lower values indicate better perceptual quality.
    """
    img = image.astype(np.float64)
    # Normalise to [0, 255] range
    vmin, vmax = img.min(), img.max()
    if vmax - vmin > 1e-10:
        img = (img - vmin) / (vmax - vmin) * 255.0
    else:
        return 0.0

    # MSCN coefficients
    kernel = cv2.getGaussianKernel(7, 7/6)
    kernel = kernel @ kernel.T
    mu = cv2.filter2D(img, -1, kernel)
    mu_sq = cv2.filter2D(img * img, -1, kernel)
    sigma = np.sqrt(np.abs(mu_sq - mu * mu))
    mscn = (img - mu) / (sigma + 1.0)  # +1 for numerical stability

    # Generalised Gaussian fit features (simplified)
    mscn_flat = mscn.ravel()
    alpha = mscn_flat.std()       # shape parameter proxy
    mean_mscn = np.abs(mscn_flat.mean())

    # Paired products (horizontal, vertical)
    h_pair = mscn[:, :-1] * mscn[:, 1:]
    v_pair = mscn[:-1, :] * mscn[1:, :]

    h_std = h_pair.std()
    v_std = v_pair.std()

    # BRISQUE-like score: lower = better quality
    score = float(alpha + mean_mscn + h_std + v_std)
    return score

def calculate_ssim_score(processed, reference):
    """SSIM between processed and reference (both normalised to same range)."""
    # Normalise both to [0, 1] float64
    proc = processed.astype(np.float64)
    ref  = reference.astype(np.float64)

    p_min, p_max = proc.min(), proc.max()
    r_min, r_max = ref.min(), ref.max()

    if p_max - p_min > 1e-10:
        proc = (proc - p_min) / (p_max - p_min)
    if r_max - r_min > 1e-10:
        ref = (ref - r_min) / (r_max - r_min)

    # Resize if shapes don't match
    if proc.shape != ref.shape:
        ref = cv2.resize(ref, (proc.shape[1], proc.shape[0]), interpolation=cv2.INTER_LINEAR)

    score, ssim_map = ssim(ref, proc, data_range=1.0, full=True)
    return float(score), ssim_map

# --- Compute all metrics ---
print("Step 10: Comprehensive Image Quality Metrics")
print(f"   Reference: spatial calibrated image ({calibrated_image.shape})")
print(f"   Processed: masked CLAHE-enhanced image ({masked_clahe_image.shape})\n")

# Reference metrics
mask = np.ones_like(calibrated_image)
ref_cii      = 1.0
ref_snr      = calculate_snr(calibrated_image)
ref_cnr      = calculate_cnr(calibrated_image)
ref_entropy  = calculate_entropy_generic(calibrated_image)
ref_eme      = ImageMetrics.calculate_eme(calibrated_image, 4, 4)
ref_brisque  = calculate_brisque_features(calibrated_image)

# Processed metrics
proc_cii     = ImageMetrics.calculate_cii(masked_clahe_image, calibrated_image, mask)
proc_snr     = calculate_snr(masked_clahe_image)
proc_cnr     = calculate_cnr(masked_clahe_image)
proc_entropy = calculate_entropy_generic(masked_clahe_image)
proc_eme     = ImageMetrics.calculate_eme(masked_clahe_image, 4, 4)
proc_brisque = calculate_brisque_features(masked_clahe_image)

# SSIM (full-reference)
ssim_score, ssim_map = calculate_ssim_score(masked_clahe_image, calibrated_image)
save_stage_image("10_ssim_map", ssim_map)

metrics_payload = {
    "reference": {
        "cii": float(ref_cii),
        "snr": float(ref_snr),
        "cnr": float(ref_cnr),
        "entropy": float(ref_entropy),
        "eme": float(ref_eme),
        "brisque": float(ref_brisque),
    },
    "processed": {
        "cii": float(proc_cii),
        "snr": float(proc_snr),
        "cnr": float(proc_cnr),
        "entropy": float(proc_entropy),
        "eme": float(proc_eme),
        "brisque": float(proc_brisque),
        "ssim": float(ssim_score),
    },
}
with open(METRIC_DIR / "step10_metrics.json", "w", encoding="utf-8") as f:
    json.dump(metrics_payload, f, indent=2)
print(f"Saved metrics: {METRIC_DIR / 'step10_metrics.json'}")

# --- Print summary table ---
print(f"{'Metric':>12}  {'Reference':>12}  {'Processed':>12}  {'Change':>12}")
print(f"{'-'*54}")
print(f"{'CII':>12}  {'1.0000':>12}  {proc_cii:>12.4f}  {'—':>12}")
print(f"{'SNR':>12}  {ref_snr:>12.4f}  {proc_snr:>12.4f}  {proc_snr - ref_snr:>+12.4f}")
print(f"{'CNR':>12}  {ref_cnr:>12.4f}  {proc_cnr:>12.4f}  {proc_cnr - ref_cnr:>+12.4f}")
print(f"{'Entropy':>12}  {ref_entropy:>12.4f}  {proc_entropy:>12.4f}  {proc_entropy - ref_entropy:>+12.4f}")
print(f"{'EME':>12}  {ref_eme:>12.4f}  {proc_eme:>12.4f}  {proc_eme - ref_eme:>+12.4f}")
print(f"{'BRISQUE':>12}  {ref_brisque:>12.4f}  {proc_brisque:>12.4f}  {proc_brisque - ref_brisque:>+12.4f}")
print(f"{'SSIM':>12}  {'—':>12}  {ssim_score:>12.4f}  {'—':>12}")

# --- Bar chart comparison ---
metric_names = ['CII', 'SNR', 'CNR', 'Entropy', 'EME']
ref_vals  = [ref_cii, ref_snr, ref_cnr, ref_entropy, ref_eme]
proc_vals = [proc_cii, proc_snr, proc_cnr, proc_entropy, proc_eme]

fig, axes = plt.subplots(2, 3, figsize=(18, 10))
all_ax = axes.ravel()

for i, (name, rv, pv) in enumerate(zip(metric_names, ref_vals, proc_vals)):
    all_ax[i].bar(['Reference', 'Processed'], [rv, pv], color=['steelblue', 'coral'])
    all_ax[i].set_title(name, fontsize=13, fontweight='bold')
    all_ax[i].set_ylabel('Value')
    for j, v in enumerate([rv, pv]):
        all_ax[i].text(j, v, f'{v:.2f}', ha='center', va='bottom', fontsize=10)

# BRISQUE (lower is better)
all_ax[5].bar(['Reference', 'Processed'], [ref_brisque, proc_brisque], color=['steelblue', 'coral'])
all_ax[5].set_title('BRISQUE (lower=better)', fontsize=13, fontweight='bold')
all_ax[5].set_ylabel('Score')
for j, v in enumerate([ref_brisque, proc_brisque]):
    all_ax[5].text(j, v, f'{v:.2f}', ha='center', va='bottom', fontsize=10)

plt.suptitle('Step 10: Quality Metrics - Reference vs Processed', fontsize=14)
plt.tight_layout()
plt.show()

# --- SSIM Map ---
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Normalise reference for display
ref_disp = calibrated_image.astype(np.float64)
ref_disp = (ref_disp - ref_disp.min()) / (ref_disp.max() - ref_disp.min() + 1e-10)

proc_disp = masked_clahe_image.astype(np.float64)
proc_disp = (proc_disp - proc_disp.min()) / (proc_disp.max() - proc_disp.min() + 1e-10)

axes[0].imshow(ref_disp, cmap='gray')
axes[0].set_title('Reference (Calibrated)', fontsize=12)
axes[0].axis('off')

axes[1].imshow(proc_disp, cmap='gray')
axes[1].set_title('Processed (Masked CLAHE)', fontsize=12)
axes[1].axis('off')

# Resize ssim_map if needed
ssim_map_disp = ssim_map
if ssim_map.shape != ref_disp.shape:
    ssim_map_disp = cv2.resize(ssim_map.astype(np.float64),
                                (ref_disp.shape[1], ref_disp.shape[0]),
                                interpolation=cv2.INTER_LINEAR)

im = axes[2].imshow(ssim_map_disp, cmap='RdYlGn', vmin=0, vmax=1)
axes[2].set_title(f'SSIM Map (mean={ssim_score:.4f})', fontsize=12)
axes[2].axis('off')
plt.colorbar(im, ax=axes[2], fraction=0.046, pad=0.04)

plt.suptitle('Step 10: SSIM - Structural Similarity Map', fontsize=14)
plt.tight_layout()
plt.show()

print(f"\n   SSIM score: {ssim_score:.4f}  (1.0 = identical to reference)")
print(f"   BRISQUE score: {proc_brisque:.4f}  (lower = better perceptual quality)")
# Out:
# Step 10: Comprehensive Image Quality Metrics
#    Reference: spatial calibrated image ((2959, 3685))
#    Processed: masked CLAHE-enhanced image ((2959, 3685))
#
# Saved stage image: output\playground_exports\20260615_233214\stages\10_ssim_map.tiff
# Saved metrics: output\playground_exports\20260615_233214\metrics\step10_metrics.json
#       Metric     Reference     Processed        Change
# ------------------------------------------------------
#          CII        1.0000        1.0000             —
#          SNR        2.6134        2.6659       +0.0525
#          CNR        4.8368        4.4653       -0.3715
#      Entropy        7.3083        7.3288       +0.0206
#          EME       86.4930      168.7667      +82.2736
#      BRISQUE        0.2070        0.1368       -0.0702
#         SSIM             —        0.9722             —
# Saved figure: output\playground_exports\20260615_233214\figures\figure_018.png
# ...

# %% [markdown]
# ## Step 11: Normalize & Resize
#
# Normalize the image to 16-bit range (0–65535) and resize to `OUTPUT_WIDTH` while preserving aspect ratio using bilinear interpolation (GPU-accelerated when available).
#
# **Key parameter:** `OUTPUT_WIDTH` (**4096**): target width in pixels. Set to 0 to skip resizing.

# %%
# ============================================================
# Step 11: Normalize & Resize
# ============================================================
# Normalize to 16-bit
img_gpu = cp.asarray(masked_clahe_image)
min_val = float(img_gpu.min())
max_val = float(img_gpu.max())
img_normalized = ((img_gpu - min_val) / (max_val - min_val) * 65535)

# Resize
final_image = _to_numpy(ImageResizer.resize(img_normalized, OUTPUT_WIDTH))

print(f"Step 11: Normalize & Resize completed")
print(f"   Normalized range: [{min_val:.2f}, {max_val:.2f}] -> [0, 65535]")
print(f"   Original size : {masked_clahe_image.shape[1]}x{masked_clahe_image.shape[0]}")
print(f"   Resized to    : {final_image.shape[1]}x{final_image.shape[0]}")
print(f"   Output dtype  : {final_image.dtype}")
print(f"   Min: {final_image.min():.2f}, Max: {final_image.max():.2f}, Mean: {final_image.mean():.2f}")
save_stage_image("11_final_resized", final_image)

# Display
fig, axes = plt.subplots(1, 2, figsize=(14, 6))
axes[0].imshow(masked_clahe_image, cmap='gray')
axes[0].set_title(f'Masked CLAHE Before Resize ({masked_clahe_image.shape[1]}x{masked_clahe_image.shape[0]})')
axes[0].axis('off')

axes[1].imshow(final_image, cmap='gray')
axes[1].set_title(f'Normalized & Resized ({final_image.shape[1]}x{final_image.shape[0]})')
axes[1].axis('off')

plt.suptitle('Step 11: Normalize & Resize', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# Step 11: Normalize & Resize completed
#    Normalized range: [0.00, 65535.00] -> [0, 65535]
#    Original size : 3685x2959
#    Resized to    : 4096x3289
#    Output dtype  : float64
#    Min: 0.00, Max: 65525.71, Mean: 37022.74
# Saved stage image: output\playground_exports\20260615_233214\stages\11_final_resized.tiff
# Saved figure: output\playground_exports\20260615_233214\figures\figure_020.png

# %% [markdown]
# ## Step 12: Final Comparison & Summary
#
# Side-by-side comparison of every processing stage output, plus a complete summary of all parameters used and quality metrics achieved. Useful for tuning: adjust parameters in Step 0b, re-run, and compare.

# %%
# ============================================================
# Step 12: Final Comparison & Summary
# ============================================================

# --- Full pipeline visual summary (all 9 stages) ---
stages = {
    '1. Raw\nProjection': proj_image,
    '2. FFC': ffc_image,
    '3. Calibrated': calibrated_image,
    '4. Filtered\nResidue': filtered_residue,
    '5. Reconstructed\n(BIMFs+Residue)': denoised_image,
    '6. Gamma\nCorrected': gamma_image,
    '7. CLAHE\nRaw': clahe_image,
    '8. Masked\nCLAHE': masked_clahe_image,
    '9. Final\n(Resized)': final_image,
}

fig, axes = plt.subplots(3, 3, figsize=(22, 16))
for ax, (title, img) in zip(axes.ravel(), stages.items()):
    ax.imshow(img, cmap='gray')
    ax.set_title(title, fontsize=12)
    ax.axis('off')

plt.suptitle('Full Pipeline - All Stages', fontsize=16, y=1.01)
plt.tight_layout()
plt.show()

# --- Summary table ---
print("=" * 70)
print("            FULL PIPELINE - PROCESSING SUMMARY")
print("=" * 70)
print(f"  Projection     : {PROJ_IMG_PATH}")
print(f"  Gain           : {GAIN_IMG_PATH}")
print(f"  Dark           : {DARK_IMG_PATH}")
print(f"  Calibration    : {CALIB_PATH}")
print(f"  Original size  : {proj_image.shape[1]}x{proj_image.shape[0]}")
print(f"  Calibrated size: {calibrated_image.shape[1]}x{calibrated_image.shape[0]}")
print(f"  Final size     : {final_image.shape[1]}x{final_image.shape[0]}")
print("-" * 70)
print(f"  FFC median     : {FFC_MEDIAN_SIZE}")
print(f"  Decomposition  : {DECOMPOSITION_METHOD.upper()}")
if DECOMPOSITION_METHOD == "fabemd":
    print(f"    FABEMD       : max_sift={FABEMD_MAX_SIFT}, sd={FABEMD_SD_THRESH}, "
          f"min_ext={FABEMD_MIN_EXTREMA}, max_bimfs={FABEMD_MAX_BIMFS}")
    print(f"    Window       : cap={FABEMD_WIN_CAP}, initial={FABEMD_INITIAL_WINDOW}, "
          f"growth_rate={FABEMD_GROWTH_RATE}")
else:
    print(f"    BEMD         : max_iter={BEMD_MAX_ITER}, threshold={BEMD_THRESHOLD}, "
          f"window={BEMD_WINDOW_SIZE}, extrema={BEMD_EXTREMA_COUNT}")
print(f"  BIMFs extracted: {len(bimfs)}")
print(f"  Homomorphic    : {HOMOMORPHIC_METHOD} (on residue)")
if HOMOMORPHIC_METHOD == "butterworth":
    print(f"    Butterworth  : D0={D0}, gH={PACE_GAMMA_H}, gL={PACE_GAMMA_L}, n={PACE_BW_ORDER}")
else:
    print(f"    Gaussian     : D0={D0}, Rh={RH}, Rl={RL}")
print(f"  Denoise method : {DENOISE_METHOD}")
if DENOISE_METHOD == "nlmeans":
    print(f"    NL-Means     : r={DENOISE_R}, h={NLMEANS_H}, "
          f"tw={NLMEANS_TEMPLATE}, sw={NLMEANS_SEARCH}")
else:
    print(f"    Bilateral    : r={DENOISE_R}, beta={DENOISE_BETA}")
print(f"  Gamma          : {GAMMA}")
print(f"  CLAHE          : clip={CLAHE_CLIP}, tile={CLAHE_TILE}")
print(f"  Preserve bg    : {PRESERVE_ZERO_BACKGROUND} (threshold={BACKGROUND_ZERO_THRESHOLD})")
if background_mask is not None:
    print(f"    BG pixels    : {int(background_mask.sum())}")
print("-" * 70)
print(f"  {'Metric':>12}  {'Reference':>12}  {'Processed':>12}  {'Interpretation'}")
print(f"  {'-'*60}")
print(f"  {'CII':>12}  {'1.0000':>12}  {proc_cii:>12.4f}  {'> 1 = contrast improved'}")
print(f"  {'SNR':>12}  {ref_snr:>12.4f}  {proc_snr:>12.4f}  {'drop expected after CLAHE'}")
print(f"  {'CNR':>12}  {ref_cnr:>12.4f}  {proc_cnr:>12.4f}  {'higher = better contrast'}")
print(f"  {'Entropy':>12}  {ref_entropy:>12.4f}  {proc_entropy:>12.4f}  {'higher = more info'}")
print(f"  {'EME':>12}  {ref_eme:>12.4f}  {proc_eme:>12.4f}  {'higher = better local contrast'}")
print(f"  {'BRISQUE':>12}  {ref_brisque:>12.4f}  {proc_brisque:>12.4f}  {'lower = better (natural imgs)'}")
print(f"  {'SSIM':>12}  {'--':>12}  {ssim_score:>12.4f}  {'1.0 = identical to reference'}")
print("=" * 70)

# --- Save final outputs in export folder ---
OUTPUT_FILENAME = EXPORT_ROOT / "processed_output.tiff"
cv2.imwrite(str(OUTPUT_FILENAME), final_image.astype(np.uint16))
print(f"\nSaved final output to: {OUTPUT_FILENAME}")

summary_payload = {
    "paths": {
        "projection": PROJ_IMG_PATH,
        "gain": GAIN_IMG_PATH,
        "dark": DARK_IMG_PATH,
        "calibration": CALIB_PATH,
    },
    "params": {
        "ffc_median": FFC_MEDIAN_SIZE,
        "decomposition": DECOMPOSITION_METHOD,
        "homomorphic": HOMOMORPHIC_METHOD,
        "denoise_method": DENOISE_METHOD,
        "denoise_r": DENOISE_R,
        "denoise_beta": DENOISE_BETA,
        "gamma": GAMMA,
        "clahe_clip": CLAHE_CLIP,
        "clahe_tile": list(CLAHE_TILE),
        "preserve_zero_background": PRESERVE_ZERO_BACKGROUND,
        "background_zero_threshold": BACKGROUND_ZERO_THRESHOLD,
        "background_pixels": int(background_mask.sum()) if background_mask is not None else 0,
        "output_width": OUTPUT_WIDTH,
    },
    "metrics": {
        "processed_cii": float(proc_cii),
        "processed_snr": float(proc_snr),
        "processed_cnr": float(proc_cnr),
        "processed_entropy": float(proc_entropy),
        "processed_eme": float(proc_eme),
        "processed_brisque": float(proc_brisque),
        "processed_ssim": float(ssim_score),
    },
}
with open(METRIC_DIR / "step12_summary.json", "w", encoding="utf-8") as f:
    json.dump(summary_payload, f, indent=2)
print(f"Saved summary: {METRIC_DIR / 'step12_summary.json'}")

if IS_COLAB:
    from google.colab import files
    files.download(str(OUTPUT_FILENAME))
    print("Download triggered in browser.")

# --- Cleanup GPU memory ---
if HAS_CUPY:
    cp._default_memory_pool.free_all_blocks()
gc.collect()
print("GPU memory freed. Done!")
# Out:
# Saved figure: output\playground_exports\20260615_233214\figures\figure_021.png
# ...
#             FULL PIPELINE - PROCESSING SUMMARY
# ...
#   Projection     : datacitra/Data_mentah/3-WWI-03B_Thorax_PA 3-WWI-03B 90kV40mA0,50s -8_7_2024-9.47 AM [Administrator].mdn
#   Gain           : datacitra/Gain/Trx/90_40_0,50.mdn
#   Dark           : datacitra/Dark/Trx/dark.mdn
#   Calibration    : datacitra/Kalibrasi/trx_44_35.npz
#   Original size  : 4096x3000
#   Calibrated size: 3685x2959
#   Final size     : 4096x3289
# ----------------------------------------------------------------------
#   FFC median     : 7
#   Decomposition  : FABEMD
#     FABEMD       : max_sift=1, sd=0.2, min_ext=5, max_bimfs=20
#     Window       : cap=2000, initial=None, growth_rate=2
#   BIMFs extracted: 9
#   Homomorphic    : gaussian (on residue)
#     Gaussian     : D0=40, Rh=2.5, Rl=0.99
#   Denoise method : nlmeans
#     NL-Means     : r=1, h=10.0, tw=7, sw=21
#   Gamma          : 0.8
# ...
